# %% [markdown]
# Работать с файлом california_housing_train.csv,
#
# который находится в папке sample_data.
#
# Определить среднюю стоимость дома,
#
# где кол-во людей от 0 до 500 (population).

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv')
print(df[df['population'] < 500] ['households'].mean())
# Out:
# 121.87632729544035

# %% [markdown]
# Узнать какая максимальная households в зоне минимального значения population.

# %%
min_Pop = df['population'].min()
print((df[df['population'] == min_Pop] ['households']))
# Out:
# 8232    4.0
# Name: households, dtype: float64
